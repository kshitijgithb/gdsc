# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
city_day_data = pd.read_csv("./city_day.csv")
city_hour_data = pd.read_csv("./city_hour.csv")
station_day_data = pd.read_csv("./station_day.csv")
station_hour_data = pd.read_csv("./station_hour.csv")
station_data = pd.read_csv("./stations.csv")
# Out:
# C:\Users\div80\AppData\Local\Temp\ipykernel_17924\2477612335.py:4: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   station_hour_data = pd.read_csv("./station_hour.csv")

# %% [markdown]
# ***Basic Knowledge about data***
#
# 1-->*The data contains pollution information about a city (city_hour or city_day dataframe ) and also particular station of a city represented by ( station_hour & station_day ) station id of that city*
#
#
# 2-->*The data contains information about a particular day ( city_day and station_day ) and also at some specific time stamp of a day ( city_hour and station_hour )*

# %% [markdown]
# ***Let's First analyse data set of a particular city***

# %%
series = ['City' , 'Date' , 'PM2.5' , 'PM10' , 'NO' , 'NO2' , 'CO' , 'SO2' , 'O3' , 'AQI' , 'AQI_Bucket']

# %%
city_day_data_req = city_day_data[series].copy()

# %%
city_day_data_req.isna().sum().sum()
city_day_newdata_req = city_day_data_req.dropna()

# %% [markdown]
# **Handling the missing values**

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from missingno) (1.25.2)
# Requirement already satisfied: matplotlib in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from missingno) (3.7.2)
# Requirement already satisfied: scipy in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from missingno) (1.11.2)
# Requirement already satisfied: seaborn in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from seaborn->missingno) (2.1.0)
# Requirement already satisfied: pytz>=2020.1 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\project files in vs code\gfg ecothon\final project data analysis\env\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno
msno.bar(city_day_data)
# Out:
# <Axes: >

# %%
msno.matrix(city_day_data)
# Out:
# <Axes: >

# %%
msno.heatmap(city_day_data)
# Out:
# <Axes: >

# %% [markdown]
# The data is time series and also dependent on different city.
# The data is missing in separate places and also all data is missing for some specific cities.
# So its better to remove the rows containing the missing values

# %%
city_hour_new_data = city_hour_data.dropna()
city_hour_new_data
city_day_new_data = city_day_data.dropna()
city_day_new_data
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
#          CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 2123   0.12  15.24  127.09     0.20     6.50    0.06  184.0      Moderate
# 2124   0.14  26.96  117.44     0.22     7.95    0.08  197.0      Moderate
# 2125   0.11  33.59  111.81     0.29     7.63    0.12  198.0      Moderate
# 2126   0.09  19.00  138.18     0.17     5.02    0.07  188.0      Moderate
# 2127   0.16  10.55  109.74     0.21     4.71    0.08  173.0      Moderate
# ...     ...    ...     ...      ...      ...     ...    ...           ...
# 29525  0.46   6.87   19.90     1.45     5.37    1.45   47.0          Good
# 29526  0.47   8.55   23.30     2.24    12.07    0.73   41.0          Good
# 29527  0.52  12.72   30.14     0.74     2.21    0.38   70.0  Satisfactory
# 29528  0.48   8.42   30.96     0.01     0.01    0.00   68.0  Satisfactory
# 29529  0.52   9.84   28.30     0.00     0.00    0.00   54.0  Satisfactory
#
# [6236 rows x 16 columns]

# %%
grouped_df = city_day_data.groupby(['City'])
grouped_df.last()
new_df = grouped_df.last()
new_df
new_f_df = grouped_df.first()

# %%
import plotly.express as px

# %%
plt.xticks(fontsize=10, rotation=90)
sns.scatterplot(x = 'City',y = 'PM2.5' ,data = new_df , color = 'red' , marker= 'x')
# Out:
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='City', ylabel='PM2.5'>

# %%
fig = plt.xticks(fontsize=10, rotation=90)
sns.scatterplot(x = 'City',y = 'PM10' ,data = new_df , color = 'purple' , marker= '.')
# Out:
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='City', ylabel='PM10'>

# %%
import geopandas as gpd

# %%
fp = r'./Maps_with_python-master/india-polygon.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()
# Out:
#    id                        st_nm  \
# 0 NaN  Andaman and Nicobar Islands
# 1 NaN            Arunachal Pradesh
# 2 NaN                        Assam
# 3 NaN                        Bihar
# 4 NaN                   Chandigarh
#
#                                             geometry
# 0  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...
# 1  POLYGON ((95.23643 26.68105, 95.19594 27.03612...
# 2  POLYGON ((95.19594 27.03612, 95.08795 26.94578...
# 3  POLYGON ((88.11357 26.54028, 88.28006 26.37640...
# 4  POLYGON ((76.84208 30.76124, 76.83758 30.72552...

# %%
city_day_newdata_req
station_data
merged_city_state = pd.merge(city_day_newdata_req,station_data,on='City',how = 'inner')
merged_city_state
grouped_df = merged_city_state.groupby(['City'])
new_df = grouped_df.last()
new_df
ser3 = ['PM2.5' , 'State']
req_df = new_df[ser3].copy()
req_df = req_df.sort_values('State')
req_df
# Out:
#                     PM2.5           State
# City
# Visakhapatnam       15.00  Andhra Pradesh
# Amaravati           22.00  Andhra Pradesh
# Guwahati            40.00           Assam
# Patna               35.42           Bihar
# Chandigarh          32.90      Chandigarh
# Delhi               54.01           Delhi
# Ahmedabad           40.02         Gujarat
# Gurugram            61.64         Haryana
# Jorapokhar          23.90       Jharkhand
# Bengaluru           17.50       Karnataka
# Thiruvananthapuram   2.00          Kerala
# Kochi                5.97          Kerala
# Bhopal              14.00  Madhya Pradesh
# Mumbai               3.84     Maharashtra
# Shillong            16.70       Meghalaya
# Aizawl               4.49         Mizoram
# Brajrajnagar        65.01          Odisha
# Talcher             24.85          Odisha
# Amritsar            57.67          Punjab
# Jaipur              58.79       Rajasthan
# Coimbatore          28.38      Tamil Nadu
# Chennai             15.95      Tamil Nadu
# Hyderabad           26.83       Telangana
# Kolkata             10.53     West Bengal

# %%
station_data
# Out:
#     StationId                                     StationName  \
# 0       AP001                  Secretariat, Amaravati - APPCB
# 1       AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2       AP003                      Tirumala, Tirupati - APPCB
# 3       AP004                 PWD Grounds, Vijayawada - APPCB
# 4       AP005          GVM Corporation, Visakhapatnam - APPCB
# ..        ...                                             ...
# 225     WB010                       Jadavpur, Kolkata - WBPCB
# 226     WB011    Rabindra Bharati University, Kolkata - WBPCB
# 227     WB012               Rabindra Sarobar, Kolkata - WBPCB
# 228     WB013                       Victoria, Kolkata - WBPCB
# 229     WB014              Ward-32 Bapupara, Siliguri - WBPCB
#
#                   City           State  Status
# 0            Amaravati  Andhra Pradesh  Active
# 1    Rajamahendravaram  Andhra Pradesh     NaN
# 2             Tirupati  Andhra Pradesh     NaN
# 3           Vijayawada  Andhra Pradesh     NaN
# 4        Visakhapatnam  Andhra Pradesh  Active
# ..                 ...             ...     ...
# 225            Kolkata     West Bengal  Active
# 226            Kolkata     West Bengal  Active
# 227            Kolkata     West Bengal  Active
# 228            Kolkata     West Bengal  Active
# 229           Siliguri     West Bengal     NaN
#
# [230 rows x 5 columns]

# %%
station_day_data
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 0       0.10  10.76  109.26     0.17     5.92    0.10    NaN           NaN
# 1       0.12  15.24  127.09     0.20     6.50    0.06  184.0      Moderate
# 2       0.14  26.96  117.44     0.22     7.95    0.08  197.0      Moderate
# 3       0.11  33.59  111.81     0.29     7.63    0.12  198.0      Moderate
# 4       0.09  19.00  138.18     0.17     5.02    0.07  188.0      Moderate
# ...      ...    ...     ...      ...      ...     ...    ...           ...
# 108030  0.69   4.36   30.59     1.32     7.26     NaN   50.0          Good
# 108031  0.68   3.49   38.95     1.42     7.92     NaN   65.0  Satisfactory
# 108032  0.78   5.12   38.17     3.52     8.64     NaN   63.0  Satisfactory
# 108033  0.69   5.88   29.64     1.86     8.40     NaN   57.0  Satisfactory
# 108034  0.58   2.80   13.10     1.31     7.39     NaN   59.0  Satisfactory
#
# [108035 rows x 16 columns]

# %%
name_id = pd.merge(station_day_data,station_data,on='StationId',how = 'inner')
name_id
lst = ['StationName', 'StationId']
station_name_id = pd.DataFrame(name_id[lst])
station_name_id.drop_duplicates(inplace=True)
station_name_id
# Out:
#                                          StationName StationId
# 0                     Secretariat, Amaravati - APPCB     AP001
# 951           GVM Corporation, Visakhapatnam - APPCB     AP005
# 2413                 Railway Colony, Guwahati - APCB     AS001
# 2915               DRM Office Danapur, Patna - BSPCB     BR005
# 3041      Govt. High School Shikarpur, Patna - BSPCB     BR006
# ...                                              ...       ...
# 105493                 Fort William, Kolkata - WBPCB     WB009
# 105891                     Jadavpur, Kolkata - WBPCB     WB010
# 106286  Rabindra Bharati University, Kolkata - WBPCB     WB011
# 106890             Rabindra Sarobar, Kolkata - WBPCB     WB012
# 107221                     Victoria, Kolkata - WBPCB     WB013
#
# [110 rows x 2 columns]

# %%
station_name_id[station_name_id['StationName']=='Victoria, Kolkata - WBPCB']['StationId']
# Out:
# 107221    WB013
# Name: StationId, dtype: object

# %%
para=['StationName', 'StationId']

station_id_name = station_data[para].copy()

station_id_name
# Out:
#                                         StationName StationId
# 0                    Secretariat, Amaravati - APPCB     AP001
# 1    Anand Kala Kshetram, Rajamahendravaram - APPCB     AP002
# 2                        Tirumala, Tirupati - APPCB     AP003
# 3                   PWD Grounds, Vijayawada - APPCB     AP004
# 4            GVM Corporation, Visakhapatnam - APPCB     AP005
# ..                                              ...       ...
# 225                       Jadavpur, Kolkata - WBPCB     WB010
# 226    Rabindra Bharati University, Kolkata - WBPCB     WB011
# 227               Rabindra Sarobar, Kolkata - WBPCB     WB012
# 228                       Victoria, Kolkata - WBPCB     WB013
# 229              Ward-32 Bapupara, Siliguri - WBPCB     WB014
#
# [230 rows x 2 columns]

# %%
st = 'Tirumala, Tirupati - APPCB'
station_id_name[station_id_name['StationName'] == st]['StationId']
# Out:
# 2    AP003
# Name: StationId, dtype: object

# %%
ans_df = req_df.drop_duplicates(subset = ['State'], keep = 'last')
ans_df
# Out:
#             PM2.5           State
# City
# Amaravati   22.00  Andhra Pradesh
# Guwahati    40.00           Assam
# Patna       35.42           Bihar
# Chandigarh  32.90      Chandigarh
# Delhi       54.01           Delhi
# Ahmedabad   40.02         Gujarat
# Gurugram    61.64         Haryana
# Jorapokhar  23.90       Jharkhand
# Bengaluru   17.50       Karnataka
# Kochi        5.97          Kerala
# Bhopal      14.00  Madhya Pradesh
# Mumbai       3.84     Maharashtra
# Shillong    16.70       Meghalaya
# Aizawl       4.49         Mizoram
# Talcher     24.85          Odisha
# Amritsar    57.67          Punjab
# Jaipur      58.79       Rajasthan
# Chennai     15.95      Tamil Nadu
# Hyderabad   26.83       Telangana
# Kolkata     10.53     West Bengal

# %%
merged = map_df.set_index('st_nm').join(ans_df.set_index('State'))
merged['PM2.5'] = merged['PM2.5'].replace(np.nan, 0)
merged.head()
# Out:
#                              id  \
# st_nm
# Andaman and Nicobar Islands NaN
# Arunachal Pradesh           NaN
# Assam                       NaN
# Bihar                       NaN
# Chandigarh                  NaN
#
#                                                                       geometry  \
# st_nm
# Andaman and Nicobar Islands  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...
# Arunachal Pradesh            POLYGON ((95.23643 26.68105, 95.19594 27.03612...
# Assam                        POLYGON ((95.19594 27.03612, 95.08795 26.94578...
# Bihar                        POLYGON ((88.11357 26.54028, 88.28006 26.37640...
# Chandigarh                   POLYGON ((76.84208 30.76124, 76.83758 30.72552...
#
#                              PM2.5
# st_nm
# Andaman and Nicobar Islands   0.00
# Arunachal Pradesh             0.00
# Assam                        40.00
# Bihar                        35.42
# Chandigarh                   32.90

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('State-wise Air Quality(PM2.5)', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='PM2.5',cmap='YlOrRd', linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Number of landslides"})
# Out:
# e:\project files in vs code\gfg ecothon\Final project data analysis\env\lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# <Axes: title={'center': 'State-wise Air Quality(PM2.5)'}>

# %%
good = new_f_df[new_f_df['AQI_Bucket'].str.contains("Good")]
gd = good.count()
Satisfactory = new_f_df[new_f_df['AQI_Bucket'].str.contains("Satisfactory")]
Moderate = new_f_df[new_f_df['AQI_Bucket'].str.contains("Moderate")]
Poor = new_f_df[new_f_df['AQI_Bucket'].str.startswith("Poor")]
Very_poor = new_f_df[new_f_df['AQI_Bucket'].str.contains("Very Poor")]
Severe = new_f_df[new_f_df['AQI_Bucket'].str.contains("Severe")]
sd = Satisfactory.count()
md = Moderate.count()
poord = Poor.count()
vpd = Very_poor.count()
sed = Severe.count()
list1 = ["Good" , "Satisfactory" , "Very Poor" , "Severe" , "Poor", "Moderate"]
list2 = [gd.Date , sd.Date , vpd.Date , sed.Date , poord.Date , md.Date]

# %%
good.reset_index(inplace=True)
good['City']
# Out:
# 0              Shillong
# 1    Thiruvananthapuram
# Name: City, dtype: object

# %%
df5 = pd.DataFrame(list(zip(list1,list2)),columns=["AQI_Bucket" , "Number of cities"])
df5
# Out:
#      AQI_Bucket  Number of cities
# 0          Good                 2
# 1  Satisfactory                10
# 2     Very Poor                 3
# 3        Severe                 2
# 4          Poor                 2
# 5      Moderate                 7

# %%
fig = px.pie(df5, values='Number of cities', names='AQI_Bucket', title='Air Quality Condition' , hole=0.7)
fig.add_annotation(dict(x=0.5, y=0.3,  align='center',
                        xref = "paper", yref = "paper",
                        showarrow = False, font_size=22,
                        text="Category"))
fig.add_layout_image(
    dict(
        source="https://png.pngtree.com/element_our/20200702/ourlarge/pngtree-environmental-protection-industry-pollution-building-elements-image_2288148.jpg",
        xref="paper", yref="paper",
        x=0.5, y=0.34,
        sizex=0.4, sizey=0.4,
        xanchor="center", yanchor="bottom", sizing= "contain",
    )
)

# %%
#Make a graph where user enters the input and then we show the graph related to that input
city = "Visakhapatnam"

# %%
ser = ["City" , "Date" ,  "PM2.5"  , "PM10"]

# %%
city_day_data_PM = city_day_data[ser].copy()
city_day_data_PM
city_day_data_PM.dropna(inplace = True)
city_specific_data = city_day_data_PM[city_day_data_PM['City'] == city]

# %%
fig = px.line(city_specific_data, x="Date", y="PM2.5", title='Air quality vs Time')
fig.show()

# %%
fig = px.line(city_specific_data, x="Date", y="PM10", title='Air quality of city with Time')
fig.show()

# %%
st = 'Tirumala, Tirupati - APPCB'
station_id_name[station_id_name['StationName'] == st]['StationId']

# %%
stationid = "AP001"

# %%
ser2 = ["StationId" , "Date" ,  "PM2.5"  , "PM10"]

# %%
station_day_data_PM = station_day_data[ser2].copy()
station_day_data_PM.dropna(inplace = True)
station_specific_data = station_day_data_PM[station_day_data_PM['StationId'] == stationid]

# %%
fig = px.line(station_specific_data, x="Date", y="PM10", title='Air quality of stations with Time')
fig.show()
